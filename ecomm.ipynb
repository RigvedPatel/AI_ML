# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("ecommerce_product_dataset2.csv")

#SHOWING THE DATA
print(data)

#USING PAIRPLOT FOR TWO VARIABLES
sns.jointplot(x="Price", y="Sales" , data=data, alpha=0.5)
#sns.pairplot(data, kind="kde", plot_kws={'alpha':0.6})
#sns.pairplot(data, hue="Category", kind="scatter", diag_kind="kde", corner=True)

sns.lmplot(x="Price", y="Sales" , data=data, scatter_kws={'alpha':0.5})

#TRAINING THR MODEL
from sklearn.model_selection import train_test_split
X= data[['Price','Rating', 'NumReviews','StockQuantity','Discount']]
y= data['Sales']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)

y_train


from sklearn.linear_model import LinearRegression 
lr=LinearRegression()
lr.fit(X_train, y_train)

lr.coef_

#prediction
pre= lr.predict(X_test)
print(pre)

sns.scatterplot(x=pre, y= y_test)
plt.xlabel("predicted")

#THIS PART I HAD ERROR SO I GOT THR SOLUTIONS IN CHATGPT
X = data[['Price']]           
y = data['Sales']             

lr.fit(X, y)

# Scatter actual data
plt.scatter(data['Price'], data['Sales'], color='blue', label='Actual')

# Regression line
plt.plot(data['Price'], lr.predict(X), color='red', label='Prediction')

# Labels and legend
plt.xlabel("Price")
plt.ylabel("Sales")
plt.title("Regression Line - Price vs Sales")
plt.legend()                                                               # tells the viewer what each color or line represents.
plt.show()
# Out:
#      ProductID       ProductName     Category   Price  Rating  NumReviews  \
# 0            1        Headphones  Electronics  400.31     1.7        3772
# 1            2        Headphones  Electronics  235.03     2.3        2919
# 2            3        Smartwatch  Electronics  417.90     1.8        1184
# 3            4        Smartphone  Electronics  152.70     3.4        2047
# 4            5            Laptop  Electronics  394.74     1.8        1267
# ..         ...               ...          ...     ...     ...         ...
# 995        996     Throw Blanket     Blankets  207.72     2.3        1973
# 996        997    Fleece Blanket     Blankets  268.60     3.2         841
# 997        998     Throw Blanket     Blankets   92.74     2.8        3454
# 998        999  Weighted Blanket     Blankets  152.28     1.3        2850
# 999       1000     Throw Blanket     Blankets  136.53     2.0        4055
#
#      StockQuantity  Discount  Sales   DateAdded           City  \
# ...
